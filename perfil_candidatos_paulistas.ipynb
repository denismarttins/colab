# %% [markdown]
# <a href="https://colab.research.google.com/github/denismarttins/colab/blob/main/perfil_candidatos_paulistas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_excel("/content/drive/MyDrive/Sheets/consulta_cand_2022_SP.xlsx")

# %%
df.dtypes
# Out:
# DS_CARGO                            object
# NR_CANDIDATO                         int64
# NM_CANDIDATO                        object
# NM_URNA_CANDIDATO                   object
# NR_CPF_CANDIDATO                     int64
# NM_EMAIL                            object
# DS_SITUACAO_CANDIDATURA             object
# CD_DETALHE_SITUACAO_CAND             int64
# DS_DETALHE_SITUACAO_CAND            object
# TP_AGREMIACAO                       object
# NR_PARTIDO                           int64
# SG_PARTIDO                          object
# NM_PARTIDO                          object
# NR_FEDERACAO                         int64
# NM_MUNICIPIO_NASCIMENTO             object
# DT_NASCIMENTO               datetime64[ns]
# NR_IDADE_DATA_POSSE                  int64
# DS_GENERO                           object
# DS_GRAU_INSTRUCAO                   object
# DS_ESTADO_CIVIL                     object
# DS_COR_RACA                         object
# DS_OCUPACAO                         object
# ...

# %%
filtro = df[["NM_CANDIDATO","NM_EMAIL","DS_SITUACAO_CANDIDATURA","NM_MUNICIPIO_NASCIMENTO","NR_IDADE_DATA_POSSE","DS_GENERO","DS_GRAU_INSTRUCAO","DS_ESTADO_CIVIL","DS_COR_RACA","DS_OCUPACAO"]]

# %%
display(filtro)
# Out:
#                           NM_CANDIDATO  \
# 0              ELIANA OLIVEIRA DE LIMA
# 1          PAULO DE TARSO NUNES CHIODE
# 2            LUCILIO FERREIRA DA SILVA
# 3      CRISTIANO MOREIRA PINTO BERALDO
# 4     JEFFERSON RODRIGO GOMES DA SILVA
# ...                                ...
# 3606          EMERSON DE ABREU SANTANA
# 3607          ANDERSON MARTINS SALGADO
# 3608         RICARDO DA CRUZ FERNANDES
# 3609                JANETE ROCHA PIETÁ
# 3610         ERIKA STANCOLOVICHE VEIGA
#
#                                      NM_EMAIL DS_SITUACAO_CANDIDATURA  \
# 0                         LILI23EOL@GMAIL.COM              CADASTRADO
# 1                         PTNCHIODE@GMAIL.COM              CADASTRADO
# 2                 LUCYLIOFERREIRA@HOTMAIL.COM              CADASTRADO
# 3       CRISTIANOBERALDOUNIAOBRASIL@GMAIL.COM                  INAPTO
# 4                  JEFF1411.RODRIGO@GMAIL.COM              CADASTRADO
# ...

# %%
sns.catplot(y="DS_GENERO", kind="count", palette="ch:s=-.2,r=.6",data=filtro)

# %%
sns.catplot(y="DS_GRAU_INSTRUCAO", kind="count", palette="ch:start=.2,rot=-.3",data=filtro)

# %%
sns.catplot(y="DS_ESTADO_CIVIL", kind="count", palette="ch:start=.2,rot=-.3",data=filtro)

# %%
sns.catplot(y="DS_COR_RACA", kind="count", palette="ch:start=.2,rot=-.3",data=filtro)

# %%
sns.catplot(y="DS_OCUPACAO", kind="count", palette="ch:start=.2,rot=-.3",data=filtro.head(50))
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:88: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   self._figure.tight_layout(*args, **kwargs)
